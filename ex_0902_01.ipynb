# %%
# 증감식이 
# +일때는 조건식의 연산자가 < 가 들어가고
# -일때는 조건식의 연산자가 >= 가 들어간다.

i = 10
end = 5
while i >= 5 :
    print(i)
    i-=1
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
i =1
end =10
while(i <=end) :
    str_i = str(i)
    print("hello"+str_i)
    i+=1
# Out:
# hello1
# hello2
# hello3
# hello4
# hello5
# hello6
# hello7
# hello8
# hello9
# hello10

# %%
i =1
end =40
while(i <= end) :
    j=1
    while j <= i :
        if i % j == 0 and j!=i:
            print(j,"j입니다")
            j+=1
        else :
            print(i,"i입니다")

    i+=1
# Out:
# 1 i입니다
# 1 j입니다
# 1 j입니다
# 3 i입니다
# 1 j입니다
# 3 j입니다
# 1 j입니다
# 3 j입니다
# 5 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 15 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 15 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 15 j입니다
# 17 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 15 j입니다
# 17 j입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 15 j입니다
# 17 j입니다
# 19 i입니다
# 1 j입니다
# 3 j입니다
# 5 j입니다
# 7 j입니다
# 9 j입니다
# 11 j입니다
# 13 j입니다
# 15 j입니다
# ...

# %%
n=1
end =9

while n <= end :
    str_n = str(n)
    str_end = str(end)
    result = 5 * n
    
    print ("5 x " + str_n + " = " +str(result))
    n+=1
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45

# %%
ls_list_test_1 = ["I","am","a","man","of","my","word"]

# %%
# ls_list_test1의 요소값 중 "man"을 가져와서 출력하시오
print(ls_list_test_1[3])
# Out:
# man

# %%
ls_list_test_1[3] = "woman"
ls_list_test_1
# Out:
# ['I', 'am', 'a', 'woman', 'of', 'my', 'word']

# %%
dict_dictionary_test1 = {"I":"나는", "am":"입니다.","a" :"어떤", "man":"남자"}

# %%
# dict_dictionary_test1의 아이템의 값 중 어떤을 가져와서 출력하시오.
print(dict_dictionary_test1["a"])
# Out:
# 어떤

# %%
# dict_dictionary_test1의 아이템의 값 중 "어떤"을 "한"으로 수정하세요.
dict_dictionary
